# %%
# !pip install pandas
# !pip install numpy
# Out:
# Collecting nba_api
#   Downloading nba_api-1.11.4-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\divya\anaconda3\lib\site-packages (from nba_api) (2.2.5)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\divya\anaconda3\lib\site-packages (from nba_api) (2.2.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\divya\anaconda3\lib\site-packages (from nba_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\divya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\divya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\divya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\divya\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2026.4.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\divya\anaconda3\lib\site-packages (from pandas>=2.2.0->nba_api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\divya\anaconda3\lib\site-packages (from pandas>=2.2.0->nba_api) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\divya\anaconda3\lib\site-packages (from pandas>=2.2.0->nba_api) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\divya\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nba_api) (1.17.0)
# Downloading nba_api-1.11.4-py3-none-any.whl (322 kB)
# Installing collected packages: nba_api
# Successfully installed nba_api-1.11.4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from nba_api.stats.endpoints import leaguegamefinder
import os
from PIL import Image
from IPython.display import IFrame

# %%
dict = {"a":[11,12,13],"b":[45,56,78]}

# %%
df = pd.DataFrame(dict)
df
# Out:
#     a   b
# 0  11  45
# 1  12  56
# 2  13  78

# %%
df.head()
# Out:
#     a   b
# 0  11  45
# 1  12  56
# 2  13  78

# %%
df.mean()
# Out:
# a    12.000000
# b    59.666667
# dtype: float64

# %%
def one_dict(list_dict):
    keys = list_dict[0].keys()
    out_dict ={key:[] for key in keys}
    for dict_ in list_dict:
        for key, value in dict_.items():
            out_dict[key].append(value)
    return out_dict

# %%
url = 'https://www.ibm.com/'
r = requests.get(url)
r.status_code
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.32.3', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=19761B38BE543C6A495804429B7A1C72~-1~...~-1~-1~-1~-1~-1; bm_sz=A254A0841FE65ED3A226862C0642EBA2~~3360308~4277062'}

# %%
print(r.request.body)
# Out:
# None

# %%
headers = r.headers
print(headers)
# Out:
# {'Content-Security-Policy': 'upgrade-insecure-requests', 'x-frame-options': 'SAMEORIGIN', 'Last-Modified': 'Sat, 11 Jul 2026 14:12:43 GMT', 'ETag': '"30e7e-65656736062bd-gzip"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/html;charset=utf-8', 'X-Content-Type-Options': 'nosniff', 'Cache-Control': 'max-age=600', 'Expires': 'Sat, 11 Jul 2026 14:54:45 GMT', 'X-Akamai-Transformed': '0 - 0 -', 'Content-Encoding': 'gzip', 'Date': 'Sat, 11 Jul 2026 14:44:45 GMT', 'Content-Length': '41322', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000'}

# %%
headers['Date']
# Out:
# 'Sat, 11 Jul 2026 14:44:45 GMT'

# %%
headers['Content-Type']
# Out:
# 'text/html;charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'
