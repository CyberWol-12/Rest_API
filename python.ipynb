# %%
# !pip install pandas
# !pip install numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dict = {"a":[11,12,13],"b":[45,56,78]}

# %%
df = pd.DataFrame(dict)
df
# Out:
#     a   b
# 0  11  45
# 1  12  56
# 2  13  78

# %%
df.head()
# Out:
#     a   b
# 0  11  45
# 1  12  56
# 2  13  78

# %%
df.mean()
# Out:
# a    12.000000
# b    59.666667
# dtype: float64
